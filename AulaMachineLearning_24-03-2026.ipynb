# %% [markdown]
# <a href="https://colab.research.google.com/github/RamonSantos10/ML-DSM/blob/main/AulaMachineLearning_24-03-2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introdução de Python

# %%
print('Hello World!')
# Out:
# Hello World!

# %% [markdown]
# ## Bibliotecas e Funções de Python

# %%
import math

def equacao2grau(a, b, c):
  delta = b**2 - 4 * a * c

  if delta < 0:
    return f'Número sem raiz {delta}'

  x1 = (- b + math.sqrt(delta)) / (2 * a)
  x2 = (- b - math.sqrt(delta)) / (2 * a)

  return x1, x2

# %%
eq = equacao2grau(1, -3, 2)
print(eq)
# Out:
# (2.0, 1.0)

# %%
import random

for i in range(5):
  a = random.randint(-5, 5)
  b = random.randint(-10, 10)
  c = random.randint(-10, 10)
  eq += equacao2grau(a, b, c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3356/692957177.py in <cell line: 0>()
#       5   b = random.randint(-10, 10)
#       6   c = random.randint(-10, 10)
# ----> 7   eq += equacao2grau(a, b, c)
#
# TypeError: can only concatenate tuple (not "str") to tuple

# %%
for i in range(12):
  if(i % 2 == 0):
    if (eq[i] != 'Número sem raíz'):
      print('X1: [',f"{eq[i]:.2f}",']')
    else:
      if(eq[i] != 'Número sem raíz'):
        print('X2: [',f"{eq[i]:.2f}",']')
